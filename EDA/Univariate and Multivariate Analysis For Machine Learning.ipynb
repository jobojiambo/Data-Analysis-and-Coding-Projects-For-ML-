# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# Univariate analysis is a statistical method used to analyze data that involves only one variable. In other words, it involves analyzing the characteristics of a single variable, such as its frequency, distribution, central tendency, variability, and any outliers or extreme values.

# %% [markdown]
# # Importing a sample dataset from Scikit Learn
# The iris flower is a genus of flowering plants that belong to the family Iridaceae. It is a popular ornamental plant, known for its showy and colorful blooms.The iris flower is also well-known in the field of biology and statistics as it has been used extensively as a model organism for studying genetics and data analysis.

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()
# Let's convert to dataframe 
iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']],columns= iris['feature_names'] + ['species'])
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0        0.0
# ...

# %%
#Collecting some few inferential statistics
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
#The columns ‘species’ is categorical, so lets check the frequency distribution for each category.
print(iris['species'].value_counts())
# Out:
# 0.0    50
# 1.0    50
# 2.0    50
# Name: species, dtype: int64

# %% [raw]
# From the above We can see that 'species' has 3 category with 50 records each. ie: setosa 50, versicolor, 50 virginica, 50

# %%
# replace the values with class labels 
t = iris.species = np.where(iris.species == 0.0, 'setosa', np.where(iris. species==1.0,'versicolor', 'virginica'))
t
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
# let's remove spaces from column name 
iris.columns = iris.columns.str.replace(' ','') ;iris.describe()
# Out:
#        sepallength(cm)  sepalwidth(cm)  petallength(cm)  petalwidth(cm)
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.843333        3.057333         3.758000        1.199333
# std           0.828066        0.435866         1.765298        0.762238
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
j = iris['sepallength(cm)']
k = iris['petallength(cm)']

# %% [markdown]
# ### Pandas dataframe visualization

# %%
# Asimple visualization of the sepal length against petal length
plt.scatter(j,k)

# %%
print(iris['species'].value_counts())
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# Set the size of the plot 
iris.hist()
plt.suptitle("Histogram", fontsize=16) # use suptitle to add title to all sublots 
plt.show()

# %%
iris.boxplot()
plt.title("Bar Plot", fontsize=16) 
plt.show()

# %%
# print the mean length(in cm) for each column by species 
iris.groupby(by = "species").mean()
# Out:
#             sepallength(cm)  sepalwidth(cm)  petallength(cm)  petalwidth(cm)
# species
# setosa                5.006           3.428            1.462           0.246
# versicolor            5.936           2.770            4.260           1.326
# virginica             6.588           2.974            5.552           2.026

# %% [markdown]
# # Multivariate analysis
# In multivariate analysis I tried to establish a sense of relationship of all variables with one other

# %%
# plot for mean of each feature for each label class 
iris.groupby(by = "species").mean().plot(kind="bar")
plt.title('Class vs Measurements') 
plt.ylabel('mean measurement(cm)') 
plt.xticks(rotation=0)  # manage the xticks rotation plt.grid(True)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
# creating correlation matrix 
corr = iris.corr()
corr
# Out:
#                  sepallength(cm)  sepalwidth(cm)  petallength(cm)  \
# sepallength(cm)         1.000000       -0.117570         0.871754
# sepalwidth(cm)         -0.117570        1.000000        -0.428440
# petallength(cm)         0.871754       -0.428440         1.000000
# petalwidth(cm)          0.817941       -0.366126         0.962865
#
#                  petalwidth(cm)
# sepallength(cm)        0.817941
# sepalwidth(cm)        -0.366126
# petallength(cm)        0.962865
# petalwidth(cm)         1.000000

# %% [raw]
# The correlation function used Pearson correlation coefficient, which results in a number between -1 to 1. A strong negative relationship is indicated by a coefficient closer to -1 and a strong positive correlation is indicated by a coefficient toward

# %%
import statsmodels.api as sm 
sm.graphics.plot_corr(corr, xnames=list(corr.columns)) 
plt.show()

# %% [raw]
# Although unrelated to the above statistical analysis, I used python dictionaries to create a simple dataframe to establish the relationship between hours studied and and the grades of a sudent

# %%
df_2 = pd.DataFrame({'Hours_studied':[2,3,4,5],
          'Test_Grade':[57,66,73,76]},
           index = [0,1,2,3])
df_2
# Out:
#    Hours_studied  Test_Grade
# 0              2          57
# 1              3          66
# 2              4          73
# 3              5          76

# %%
# Simple scatter plot 
df_2.plot(kind='scatter', x='Hours_studied', y='Test_Grade', title='Grade vs Hours Studied')
# Out:
# <AxesSubplot:title={'center':'Grade vs Hours Studied'}, xlabel='Hours_studied', ylabel='Test_Grade'>

# %% [markdown]
# # Pair Plot
# You can understand the relationship attributes by looking at the distribution of the interactions of each pair of attributes. This uses a built-in function to create a matrix of scatter plots of all attributes against all attributes

# %%
# use the scatter_matrix function from pandas.plotting
pd.plotting.scatter_matrix(iris, figsize=(10, 10))

# use suptitle to add title to all subplots
plt.suptitle("Pair Plot", fontsize=20)

# display the plot
plt.show()

# %% [markdown]
# ## Findings From the Data Analysis:

# %% [raw]
# No missing values found in the dataset.
# Sepal length is longer than petal length. Sepal length ranges from 4.3 to 7.9 with an average length of 5.8, while petal length ranges from 1 to 6.9 with an average length of 3.7.
# Sepal width is also wider than petal width. Sepal width ranges from 2 to 4.4 with an average width of 3.05, while petal width ranges from 0.1 to 2.5 with an average width of 1.19.
# The average petal length of setosa is much smaller than that of versicolor and virginica. However, the average sepal width of setosa is higher than versicolor and virginica.
# Petal length and width are strongly correlated. 96% of the time, the width increases with an increase in length.
# Petal length has a negative correlation with sepal width. 42% of the time, an increase in sepal width will decrease petal length.
# Based on length and width of sepal/petal alone, initial conclusion from data is that versicolor/virginica might resemble in size. However, setosa characteristics seem to be noticeably different from the other two.
